# %% [markdown]
# # Feature Selection

# %%
# to handle paths
import sys
import os
from pathlib import Path

# to handle datasets
import pandas as pd
import numpy as np

# for iterating
from itertools import product

pd.pandas.set_option('display.max_columns', 5)

# %%
# variables
project_name = "RF+Clust"
project_folder = f"C:/Users/anani/Downloads/{project_name}"
sys.path.append(project_folder)

from variables import suite_name, features, target, transformation, n_folds, budgets, algorithms
from variables import model_name, explainer_type

# %%
# define directories
data_folder = f"{project_folder}/Data/{suite_name}/preprocessed/"
results_folder = f"{project_folder}/Results/{suite_name}/transformation={transformation}_features=all/{model_name}"

# %%
def get_topn_features(path: str, n: int):
    """
    Function to read feature importance from file and get topn feature names.
    """
    feature_importance = pd.read_csv(path)
    print("Preview feature importance:")
    print(feature_importance.head())

    return feature_importance[feature_importance['rank'] <= n]['feature_name'].tolist()

# %%
for algorithm_name, budget in product(algorithms, budgets):
    print(f"Algorithm name: {algorithm_name}, budget: {budget}")
    
    # define directories
    data_folder_all_temp = f"{data_folder}/transformation={transformation}_features=all/algorithm_name={algorithm_name}_budget={budget}"
    results_folder_all_temp = f"{results_folder}/algorithm_name={algorithm_name}_budget={budget}"
    # create directories
    data_folder_selected_temp = f"{data_folder}/transformation={transformation}_features={features}/{model_name}/algorithm_name={algorithm_name}_budget={budget}"
    os.makedirs(data_folder_selected_temp, exist_ok=True)
    
    for fold_number in np.arange(1, n_folds+1):
        print(f"fold_number: {fold_number}")
        
        # load data
        X_train = pd.read_csv(f"{data_folder_all_temp}/X_train_fold={fold_number}.csv"
                                  , dtype={"f_id": int, "i_id": int}, index_col=['f_id', 'i_id'])
        X_test = pd.read_csv(f"{data_folder_all_temp}/X_test_fold={fold_number}.csv"
                                  , dtype={"f_id": int, "i_id": int}, index_col=['f_id', 'i_id'])
        y_train = pd.read_csv(f"{data_folder_all_temp}/y_train_fold={fold_number}.csv")
        y_test = pd.read_csv(f"{data_folder_all_temp}/y_test_fold={fold_number}.csv")
        
        # get topn features
        shap_importance_path = f"{results_folder_all_temp}/shap/shap_importance_set=train_fold={fold_number}.csv"
        topn_features = get_topn_features(path=shap_importance_path, n=features)
        print("\n")
        print(f"topn_features: {topn_features}")
        print(f"len topn_features: {len(topn_features)}")
        
        X_train = X_train[topn_features]
        X_test = X_test[topn_features]
        print(f"preview data: ")
        print(X_train.head(3))
        print(X_train.shape)

        # save
        X_train.reset_index().to_csv(f"{data_folder_selected_temp}/X_train_fold={fold_number}.csv", index=False)
        X_test.reset_index().to_csv(f"{data_folder_selected_temp}/X_test_fold={fold_number}.csv", index=False)
        y_train.to_csv(f"{data_folder_selected_temp}/y_train_fold={fold_number}.csv", index=False)
        y_test.to_csv(f"{data_folder_selected_temp}/y_test_fold={fold_number}.csv", index=False)
# Out:
# Algorithm name: DE1, budget: 5000
# fold_number: 1
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.432102     1
# 1                       ic.eps.max            0.355355     2
# 2  ela_meta.quad_w_interact.adj_r2            0.106794     3
# 3    ela_meta.lin_simple.intercept            0.053418     4
# 4             ela_level.qda_mda_10            0.035930     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ela_meta.lin_simple.intercept', 'ela_level.qda_mda_10', 'ic.eps.ratio', 'disp.ratio_mean_02', 'ic.eps.s', 'ela_distr.number_of_peaks', 'disp.ratio_mean_10']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  \
# f_id i_id                                            ...
# 2    1                        -0.133855   -0.037239  ...
#      2                        -0.133875   -0.032532  ...
#      3                        -0.133810    0.014485  ...
#
#            ela_distr.number_of_peaks  disp.ratio_mean_10
# f_id i_id
# 2    1                      0.902381            0.551931
#      2                      0.509546            0.518388
#      3                      1.295215            0.619746
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 2
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.483294     1
# 1    ela_meta.lin_simple.intercept            0.261077     2
# 2                     ic.eps.ratio            0.148910     3
# 3                         ic.eps.s            0.075459     4
# 4  ela_meta.quad_w_interact.adj_r2            0.056877     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.lin_simple.intercept', 'ic.eps.ratio', 'ic.eps.s', 'ela_meta.quad_w_interact.adj_r2', 'ela_level.qda_mda_10', 'ela_level.mmce_lda_10', 'ela_level.lda_mda_10', 'nbc.nn_nb.mean_ratio', 'ela_level.mmce_qda_10']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.lin_simple.intercept  ...  \
# f_id i_id                                             ...
# 1    1      -0.226713                      -0.179615  ...
#      2      -0.226713                      -0.179614  ...
#      3      -0.226713                      -0.179615  ...
#
#            nbc.nn_nb.mean_ratio  ela_level.mmce_qda_10
# f_id i_id
# 1    1                 1.155509              -0.082686
#      2                 0.827057              -1.141970
#      3                 0.858043              -1.023025
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 3
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.429633     1
# 1     ela_meta.lin_simple.coef.min            0.422484     2
# 2  ela_meta.quad_w_interact.adj_r2            0.181810     3
# 3                     ic.eps.ratio            0.048426     4
# 4             ela_level.qda_mda_10            0.039959     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.lin_simple.coef.min', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_level.qda_mda_10', 'ela_meta.lin_simple.intercept', 'ic.eps.s', 'ela_level.lda_qda_10', 'ic.m0', 'ela_level.lda_mda_10']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.lin_simple.coef.min  ...     ic.m0  \
# f_id i_id                                            ...
# 1    1      -0.236775                      -0.13411  ... -0.416597
#      2      -0.236774                      -0.13411  ... -0.784721
#      3      -0.236774                      -0.13411  ... -0.731009
#
#            ela_level.lda_mda_10
# f_id i_id
# 1    1                 0.438562
#      2                 1.352547
#      3                 1.080226
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 4
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.441822     1
# 1                       ic.eps.max            0.408599     2
# 2  ela_meta.quad_w_interact.adj_r2            0.169518     3
# 3                     ic.eps.ratio            0.095376     4
# 4             ela_level.lda_mda_10            0.062644     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_level.lda_mda_10', 'ela_level.qda_mda_10', 'ic.eps.s', 'nbc.nn_nb.mean_ratio', 'nbc.nb_fitness.cor', 'nbc.dist_ratio.coeff_var']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  nbc.nb_fitness.cor  \
# f_id i_id                                            ...
# 1    1                         -0.13411   -0.236774  ...           -0.427867
#      2                         -0.13411   -0.236774  ...            0.042453
#      3                         -0.13411   -0.236774  ...            0.015839
#
#            nbc.dist_ratio.coeff_var
# f_id i_id
# 1    1                    -1.283028
#      2                    -0.928677
#      3                    -0.955726
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 5
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.453891     1
# 1                       ic.eps.max            0.427060     2
# 2  ela_meta.quad_w_interact.adj_r2            0.178082     3
# 3                     ic.eps.ratio            0.060856     4
# 4             ela_level.qda_mda_10            0.055291     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_level.qda_mda_10', 'ic.eps.s', 'ela_level.lda_mda_25', 'ela_level.lda_mda_10', 'disp.ratio_median_02', 'ela_level.mmce_qda_50']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  \
# f_id i_id                                            ...
# 1    1                         -0.13411   -0.236775  ...
#      2                         -0.13411   -0.236775  ...
#      3                         -0.13411   -0.236775  ...
#
#            disp.ratio_median_02  ela_level.mmce_qda_50
# f_id i_id
# 1    1                -1.242721              -0.174823
#      2                -0.899889              -0.571231
#      3                -0.927370              -0.515998
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 6
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.446956     1
# 1     ela_meta.lin_simple.coef.min            0.441134     2
# 2  ela_meta.quad_w_interact.adj_r2            0.185099     3
# 3             ela_level.qda_mda_10            0.044058     4
# 4                     ic.eps.ratio            0.039259     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.lin_simple.coef.min', 'ela_meta.quad_w_interact.adj_r2', 'ela_level.qda_mda_10', 'ic.eps.ratio', 'ela_meta.lin_simple.intercept', 'ela_level.lda_qda_10', 'ic.eps.s', 'disp.ratio_median_02', 'ic.m0']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.lin_simple.coef.min  ...  \
# f_id i_id                                            ...
# 1    1      -0.236458                       -0.1341  ...
#      2      -0.236458                       -0.1341  ...
#      3      -0.236458                       -0.1341  ...
#
#            disp.ratio_median_02     ic.m0
# f_id i_id
# 1    1                -1.268951 -0.447897
#      2                -0.927800 -0.821385
#      3                -0.955146 -0.766891
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 7
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.457082     1
# 1     ela_meta.lin_simple.coef.min            0.433777     2
# 2  ela_meta.quad_w_interact.adj_r2            0.200451     3
# 3                     ic.eps.ratio            0.053630     4
# 4             ela_level.qda_mda_10            0.042285     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.lin_simple.coef.min', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_level.qda_mda_10', 'ela_meta.lin_simple.intercept', 'ela_level.lda_qda_10', 'ic.eps.s', 'ela_level.mmce_qda_50', 'ela_level.lda_qda_50']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.lin_simple.coef.min  ...  \
# f_id i_id                                            ...
# 1    1      -0.236775                      -0.13411  ...
#      2      -0.236774                      -0.13411  ...
#      3      -0.236774                      -0.13411  ...
#
#            ela_level.mmce_qda_50  ela_level.lda_qda_50
# f_id i_id
# 1    1                 -0.144911             -0.211417
#      2                 -0.531760             -0.370879
#      3                 -0.477859             -0.364492
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 8
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.485266     1
# 1                       ic.eps.max            0.389903     2
# 2  ela_meta.quad_w_interact.adj_r2            0.186615     3
# 3                     ic.eps.ratio            0.089965     4
# 4             ela_level.qda_mda_10            0.041374     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_level.qda_mda_10', 'ic.eps.s', 'ela_level.lda_qda_10', 'ela_meta.lin_w_interact.adj_r2', 'ic.m0', 'ela_level.lda_mda_10']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...     ic.m0  \
# f_id i_id                                            ...
# 1    1                        -0.134107   -0.236516  ... -0.402759
#      2                        -0.134107   -0.236516  ... -0.769508
#      3                        -0.134107   -0.236516  ... -0.715996
#
#            ela_level.lda_mda_10
# f_id i_id
# 1    1                 0.410376
#      2                 1.306875
#      3                 1.039763
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 9
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.490190     1
# 1                       ic.eps.max            0.432758     2
# 2  ela_meta.quad_w_interact.adj_r2            0.174872     3
# 3             ela_level.qda_mda_10            0.050858     4
# 4                     ic.eps.ratio            0.042488     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ela_level.qda_mda_10', 'ic.eps.ratio', 'ela_level.mmce_qda_50', 'ela_level.lda_qda_10', 'ela_level.lda_mda_10', 'ela_meta.lin_w_interact.adj_r2', 'disp.ratio_median_02']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  \
# f_id i_id                                            ...
# 1    1                        -0.134109   -0.236614  ...
#      2                        -0.134109   -0.236613  ...
#      3                        -0.134109   -0.236613  ...
#
#            ela_meta.lin_w_interact.adj_r2  disp.ratio_median_02
# f_id i_id
# 1    1                           0.024944             -1.321529
#      2                           0.840471             -0.974427
#      3                           0.785275             -1.002250
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 10
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.482213     1
# 1  ela_meta.quad_w_interact.adj_r2            0.171695     2
# 2                         ic.h.max            0.089501     3
# 3                     ic.eps.ratio            0.058771     4
# 4             ela_level.qda_mda_10            0.050065     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.h.max', 'ic.eps.ratio', 'ela_level.qda_mda_10', 'ela_meta.lin_simple.coef.max', 'nbc.nb_fitness.cor', 'ic.eps.s', 'ela_meta.lin_simple.intercept', 'nbc.nn_nb.mean_ratio']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.quad_w_interact.adj_r2  ...  \
# f_id i_id                                               ...
# 1    1      -0.225098                         0.722737  ...
#      2      -0.225098                         0.722737  ...
#      3      -0.225098                         0.722737  ...
#
#            ela_meta.lin_simple.intercept  nbc.nn_nb.mean_ratio
# f_id i_id
# 1    1                         -0.179410              1.152351
#      2                         -0.179409              0.823655
#      3                         -0.179410              0.854664
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 11
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.535867     1
# 1                       ic.eps.max            0.407458     2
# 2  ela_meta.quad_w_interact.adj_r2            0.131381     3
# 3                     ic.eps.ratio            0.036728     4
# 4             ela_level.qda_mda_10            0.034849     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_level.qda_mda_10', 'nbc.nn_nb.mean_ratio', 'ela_level.lda_mda_25', 'ela_level.lda_qda_10', 'disp.diff_mean_02', 'nbc.dist_ratio.coeff_var']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  disp.diff_mean_02  \
# f_id i_id                                            ...
# 1    1                        -0.134017    -0.22963  ...          -1.380109
#      2                        -0.134016    -0.22963  ...          -0.983171
#      3                        -0.134017    -0.22963  ...          -1.009678
#
#            nbc.dist_ratio.coeff_var
# f_id i_id
# 1    1                    -1.247897
#      2                    -0.883183
#      3                    -0.911023
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 12
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                     ic.eps.ratio            0.182608     1
# 1                       ic.eps.max            0.113390     2
# 2             disp.ratio_median_02            0.065436     3
# 3               disp.ratio_mean_05            0.054453     4
# 4  ela_meta.quad_w_interact.adj_r2            0.048876     5
#
#
# topn_features: ['ic.eps.ratio', 'ic.eps.max', 'disp.ratio_median_02', 'disp.ratio_mean_05', 'ela_meta.quad_w_interact.adj_r2', 'ela_meta.lin_simple.coef.min', 'ela_level.mmce_qda_50', 'ic.eps.s', 'ela_level.qda_mda_50', 'ela_level.mmce_mda_50']
# len topn_features: 10
# preview data:
#            ic.eps.ratio  ic.eps.max  ...  ela_level.qda_mda_50  \
# f_id i_id                            ...
# 1    1        -0.756818   -0.382637  ...             -0.565270
#      2        -0.707385   -0.382633  ...             -0.165461
#      3        -0.717311   -0.382634  ...             -0.138616
#
#            ela_level.mmce_mda_50
# f_id i_id
# 1    1                 -0.020249
#      2                 -0.594032
#      3                 -0.533192
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 13
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.492375     1
# 1                       ic.eps.max            0.434180     2
# 2  ela_meta.quad_w_interact.adj_r2            0.173154     3
# 3                     ic.eps.ratio            0.044651     4
# 4             ela_level.qda_mda_10            0.040944     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_level.qda_mda_10', 'ic.m0', 'ela_meta.lin_simple.intercept', 'pca.expl_var_PC1.cor_init', 'ela_level.lda_qda_10', 'ic.eps.s']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  \
# f_id i_id                                            ...
# 1    1                         -0.13411   -0.236775  ...
#      2                         -0.13411   -0.236774  ...
#      3                         -0.13411   -0.236774  ...
#
#            ela_level.lda_qda_10  ic.eps.s
# f_id i_id
# 1    1                 0.043405 -0.853806
#      2                 0.169519 -0.812840
#      3                 0.209784 -0.821025
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 14
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.458423     1
# 1  ela_meta.quad_w_interact.adj_r2            0.186931     2
# 2                     ic.eps.ratio            0.181215     3
# 3                       ic.eps.max            0.120909     4
# 4                         ic.eps.s            0.057123     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ic.eps.max', 'ic.eps.s', 'ela_distr.kurtosis', 'ela_meta.lin_simple.intercept', 'disp.diff_median_02', 'disp.ratio_median_02', 'ela_distr.skewness']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ela_meta.quad_w_interact.adj_r2  ...  \
# f_id i_id                                                                 ...
# 1    1                         -0.13411                         0.710831  ...
#      2                         -0.13411                         0.710831  ...
#      3                         -0.13411                         0.710831  ...
#
#            disp.ratio_median_02  ela_distr.skewness
# f_id i_id
# 1    1                -1.282337           -0.384006
#      2                -0.940194           -0.419518
#      3                -0.967619           -0.416531
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 15
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.494765     1
# 1                       ic.eps.max            0.362856     2
# 2  ela_meta.quad_w_interact.adj_r2            0.165661     3
# 3                     ic.eps.ratio            0.083816     4
# 4             ela_level.qda_mda_10            0.040855     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_level.qda_mda_10', 'ela_level.lda_qda_10', 'ela_meta.lin_simple.coef.max', 'ela_meta.lin_simple.intercept', 'ic.eps.s', 'ela_level.lda_mda_10']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  ic.eps.s  \
# f_id i_id                                            ...
# 1    1                         -0.13411   -0.236775  ... -0.843763
#      2                         -0.13411   -0.236774  ... -0.802894
#      3                         -0.13411   -0.236774  ... -0.811059
#
#            ela_level.lda_mda_10
# f_id i_id
# 1    1                 0.421895
#      2                 1.325747
#      3                 1.056445
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 16
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.483730     1
# 1                       ic.eps.max            0.400796     2
# 2  ela_meta.quad_w_interact.adj_r2            0.178230     3
# 3                     ic.eps.ratio            0.070427     4
# 4               ela_distr.kurtosis            0.031150     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_distr.kurtosis', 'ic.eps.s', 'ela_level.qda_mda_10', 'nbc.nn_nb.mean_ratio', 'ela_level.qda_mda_50', 'ic.m0']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  \
# f_id i_id                                            ...
# 1    1                         -0.13411   -0.236775  ...
#      2                         -0.13411   -0.236775  ...
#      3                         -0.13411   -0.236775  ...
#
#            ela_level.qda_mda_50     ic.m0
# f_id i_id
# 1    1                -0.553786 -0.347055
#      2                -0.150725 -0.794210
#      3                -0.123661 -0.728967
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 17
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.475845     1
# 1                       ic.eps.max            0.344026     2
# 2  ela_meta.quad_w_interact.adj_r2            0.194014     3
# 3                     ic.eps.ratio            0.083942     4
# 4             ela_level.lda_mda_10            0.026686     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_level.lda_mda_10', 'ela_level.lda_qda_10', 'ela_level.qda_mda_10', 'ela_distr.skewness', 'ela_meta.lin_simple.intercept', 'disp.ratio_mean_02']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  \
# f_id i_id                                            ...
# 1    1                         -0.13411   -0.236775  ...
#      2                         -0.13411   -0.236775  ...
#      3                         -0.13411   -0.236775  ...
#
#            ela_meta.lin_simple.intercept  disp.ratio_mean_02
# f_id i_id
# 1    1                         -0.180905           -1.371996
#      2                         -0.180904           -1.003970
#      3                         -0.180905           -1.027922
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 18
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.497088     1
# 1                       ic.eps.max            0.355449     2
# 2  ela_meta.quad_w_interact.adj_r2            0.181009     3
# 3                     ic.eps.ratio            0.097598     4
# 4   ela_meta.lin_w_interact.adj_r2            0.019293     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_meta.lin_w_interact.adj_r2', 'ela_level.qda_mda_10', 'ela_level.lda_qda_10', 'ela_meta.lin_simple.coef.max', 'ic.m0', 'ela_meta.lin_simple.intercept']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...     ic.m0  \
# f_id i_id                                            ...
# 1    1                         -0.13411   -0.236775  ... -0.381621
#      2                         -0.13411   -0.236775  ... -0.752231
#      3                         -0.13411   -0.236775  ... -0.698157
#
#            ela_meta.lin_simple.intercept
# f_id i_id
# 1    1                         -0.180905
#      2                         -0.180904
#      3                         -0.180905
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 19
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.495855     1
# 1                       ic.eps.max            0.339406     2
# 2  ela_meta.quad_w_interact.adj_r2            0.174808     3
# 3                     ic.eps.ratio            0.069600     4
# 4             ela_level.qda_mda_10            0.026867     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_level.qda_mda_10', 'disp.ratio_median_02', 'nbc.nn_nb.cor', 'ela_distr.skewness', 'ic.eps.s', 'ela_meta.lin_simple.intercept']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  ic.eps.s  \
# f_id i_id                                            ...
# 1    1                         -0.13411   -0.236775  ... -0.875813
#      2                         -0.13411   -0.236775  ... -0.834491
#      3                         -0.13411   -0.236775  ... -0.842747
#
#            ela_meta.lin_simple.intercept
# f_id i_id
# 1    1                         -0.180905
#      2                         -0.180904
#      3                         -0.180905
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 20
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.520069     1
# 1                       ic.eps.max            0.430097     2
# 2                     ic.eps.ratio            0.084690     3
# 3  ela_meta.quad_w_interact.adj_r2            0.046473     4
# 4             ela_level.qda_mda_10            0.030222     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ic.eps.ratio', 'ela_meta.quad_w_interact.adj_r2', 'ela_level.qda_mda_10', 'ela_distr.kurtosis', 'ela_meta.quad_simple.cond', 'ic.m0', 'ela_meta.quad_simple.adj_r2', 'ela_level.lda_qda_10']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  \
# f_id i_id                                            ...
# 1    1                        -0.134109   -0.236703  ...
#      2                        -0.134109   -0.236702  ...
#      3                        -0.134109   -0.236703  ...
#
#            ela_meta.quad_simple.adj_r2  ela_level.lda_qda_10
# f_id i_id
# 1    1                        1.251473              0.043924
#      2                        1.251473              0.170001
#      3                        1.251473              0.210254
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 21
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.482968     1
# 1                       ic.eps.max            0.359450     2
# 2  ela_meta.quad_w_interact.adj_r2            0.185270     3
# 3                     ic.eps.ratio            0.083742     4
# 4                         ic.eps.s            0.023058     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ic.eps.s', 'ela_level.lda_qda_10', 'ela_level.qda_mda_10', 'ic.m0', 'ela_distr.kurtosis', 'ela_meta.lin_simple.coef.max']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  ela_distr.kurtosis  \
# f_id i_id                                            ...
# 1    1                         -0.13411   -0.236775  ...           -0.308600
#      2                         -0.13411   -0.236775  ...           -0.310625
#      3                         -0.13411   -0.236775  ...           -0.310722
#
#            ela_meta.lin_simple.coef.max
# f_id i_id
# 1    1                         -0.16852
#      2                         -0.16852
#      3                         -0.16852
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 22
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.483646     1
# 1                       ic.eps.max            0.390986     2
# 2  ela_meta.quad_w_interact.adj_r2            0.191537     3
# 3                     ic.eps.ratio            0.056959     4
# 4             ela_level.qda_mda_10            0.022365     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_level.qda_mda_10', 'ela_meta.lin_simple.intercept', 'ic.m0', 'ela_meta.lin_simple.coef.max', 'ela_level.lda_qda_10', 'ic.eps.s']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  \
# f_id i_id                                            ...
# 1    1                         -0.13411   -0.236775  ...
#      2                         -0.13411   -0.236775  ...
#      3                         -0.13411   -0.236775  ...
#
#            ela_level.lda_qda_10  ic.eps.s
# f_id i_id
# 1    1                -0.023140 -0.906120
#      2                 0.105548 -0.864140
#      3                 0.146635 -0.872527
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 23
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.478853     1
# 1                       ic.eps.max            0.391568     2
# 2  ela_meta.quad_w_interact.adj_r2            0.182766     3
# 3                     ic.eps.ratio            0.046331     4
# 4             ela_level.qda_mda_10            0.043549     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_level.qda_mda_10', 'ela_meta.lin_simple.intercept', 'ela_meta.lin_simple.coef.max', 'ela_level.mmce_qda_25', 'nbc.nn_nb.mean_ratio', 'nbc.dist_ratio.coeff_var']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  \
# f_id i_id                                            ...
# 1    1                         -0.13411   -0.236775  ...
#      2                         -0.13411   -0.236775  ...
#      3                         -0.13411   -0.236775  ...
#
#            nbc.nn_nb.mean_ratio  nbc.dist_ratio.coeff_var
# f_id i_id
# 1    1                 1.279391                 -1.373312
#      2                 0.876232                 -0.950657
#      3                 0.914266                 -0.982921
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 24
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0     ela_meta.lin_simple.coef.min            0.511793     1
# 1                       ic.eps.max            0.297459     2
# 2  ela_meta.quad_w_interact.adj_r2            0.184031     3
# 3                         ic.eps.s            0.059468     4
# 4                     ic.eps.ratio            0.044429     5
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ic.eps.max', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.s', 'ic.eps.ratio', 'pca.expl_var_PC1.cov_init', 'ela_level.lda_qda_10', 'ic.m0', 'disp.ratio_mean_02', 'ela_level.qda_mda_10']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ic.eps.max  ...  disp.ratio_mean_02  \
# f_id i_id                                            ...
# 1    1                         -0.13411   -0.236775  ...           -1.397756
#      2                         -0.13411   -0.236775  ...           -1.026870
#      3                         -0.13411   -0.236775  ...           -1.051008
#
#            ela_level.qda_mda_10
# f_id i_id
# 1    1                -0.146604
#      2                -0.163107
#      3                -0.179611
#
# [3 rows x 10 columns]
# (115, 10)
# Algorithm name: DE2, budget: 5000
# fold_number: 1
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.605265     1
# 1    ela_meta.lin_simple.intercept            0.148348     2
# 2  ela_meta.quad_w_interact.adj_r2            0.075132     3
# 3               ela_distr.skewness            0.062633     4
# 4                     ic.eps.ratio            0.045268     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.lin_simple.intercept', 'ela_meta.quad_w_interact.adj_r2', 'ela_distr.skewness', 'ic.eps.ratio', 'ela_meta.lin_simple.coef.max', 'ela_level.mmce_lda_10', 'nbc.nn_nb.cor', 'disp.ratio_mean_02', 'nbc.dist_ratio.coeff_var']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.lin_simple.intercept  ...  disp.ratio_mean_02  \
# f_id i_id                                             ...
# 2    1      -0.037239                      -0.153792  ...            0.532207
#      2      -0.032532                      -0.159765  ...            0.578649
#      3       0.014485                      -0.144025  ...            0.560167
#
#            nbc.dist_ratio.coeff_var
# f_id i_id
# 2    1                     0.139933
#      2                     0.148228
#      3                     0.197998
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 2
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.559500     1
# 1    ela_meta.lin_simple.intercept            0.088185     2
# 2  ela_meta.quad_w_interact.adj_r2            0.084068     3
# 3                     ic.eps.ratio            0.078366     4
# 4               ela_distr.skewness            0.067003     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.lin_simple.intercept', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_distr.skewness', 'ela_meta.lin_simple.coef.min', 'ic.eps.s', 'ela_level.mmce_lda_10', 'nbc.nn_nb.cor', 'ela_meta.lin_simple.coef.max']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.lin_simple.intercept  ...  nbc.nn_nb.cor  \
# f_id i_id                                             ...
# 1    1      -0.226713                      -0.179615  ...       2.078675
#      2      -0.226713                      -0.179614  ...       1.277996
#      3      -0.226713                      -0.179615  ...       1.248792
#
#            ela_meta.lin_simple.coef.max
# f_id i_id
# 1    1                        -0.167514
#      2                        -0.167514
#      3                        -0.167514
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 3
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.661189     1
# 1    ela_meta.lin_simple.intercept            0.090547     2
# 2  ela_meta.quad_w_interact.adj_r2            0.082800     3
# 3                     ic.eps.ratio            0.072119     4
# 4     ela_meta.lin_simple.coef.max            0.066448     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.lin_simple.intercept', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_meta.lin_simple.coef.max', 'ela_distr.skewness', 'ela_level.mmce_lda_10', 'nbc.nb_fitness.cor', 'disp.ratio_mean_02', 'ic.eps.s']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.lin_simple.intercept  ...  disp.ratio_mean_02  \
# f_id i_id                                             ...
# 1    1      -0.236775                      -0.180905  ...           -1.401280
#      2      -0.236774                      -0.180904  ...           -1.029871
#      3      -0.236774                      -0.180905  ...           -1.054043
#
#            ic.eps.s
# f_id i_id
# 1    1    -0.844175
#      2    -0.803296
#      3    -0.811463
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 4
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.638847     1
# 1    ela_meta.lin_simple.intercept            0.090275     2
# 2  ela_meta.quad_w_interact.adj_r2            0.076316     3
# 3                     ic.eps.ratio            0.075769     4
# 4     ela_meta.lin_simple.coef.max            0.067555     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.lin_simple.intercept', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.ratio', 'ela_meta.lin_simple.coef.max', 'ela_distr.skewness', 'ic.eps.s', 'ela_level.mmce_lda_10', 'nbc.nn_nb.cor', 'nbc.nb_fitness.cor']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.lin_simple.intercept  ...  nbc.nn_nb.cor  \
# f_id i_id                                             ...
# 1    1      -0.236774                      -0.180905  ...       2.115521
#      2      -0.236774                      -0.180904  ...       1.316982
#      3      -0.236774                      -0.180905  ...       1.287856
#
#            nbc.nb_fitness.cor
# f_id i_id
# 1    1              -0.427867
#      2               0.042453
#      3               0.015839
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 5
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.634406     1
# 1                     ic.eps.ratio            0.099122     2
# 2    ela_meta.lin_simple.intercept            0.085915     3
# 3  ela_meta.quad_w_interact.adj_r2            0.084236     4
# 4                         ic.eps.s            0.042736     5
#
#
# topn_features: ['ic.eps.max', 'ic.eps.ratio', 'ela_meta.lin_simple.intercept', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.s', 'ela_meta.lin_simple.coef.max', 'nbc.nn_nb.cor', 'nbc.nn_nb.sd_ratio', 'ela_distr.skewness', 'nbc.nb_fitness.cor']
# len topn_features: 10
# preview data:
#            ic.eps.max  ic.eps.ratio  ...  ela_distr.skewness  \
# f_id i_id                            ...
# 1    1      -0.236775     -0.806034  ...           -0.416305
#      2      -0.236775     -0.762353  ...           -0.452011
#      3      -0.236775     -0.771124  ...           -0.449008
#
#            nbc.nb_fitness.cor
# f_id i_id
# 1    1              -0.432664
#      2               0.036362
#      3               0.009822
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 6
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.571573     1
# 1    ela_meta.lin_simple.intercept            0.234589     2
# 2                     ic.eps.ratio            0.119972     3
# 3               ela_distr.skewness            0.074376     4
# 4  ela_meta.quad_w_interact.adj_r2            0.068566     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.lin_simple.intercept', 'ic.eps.ratio', 'ela_distr.skewness', 'ela_meta.quad_w_interact.adj_r2', 'ela_meta.lin_simple.coef.min', 'ela_level.mmce_lda_10', 'nbc.nb_fitness.cor', 'ic.eps.s', 'nbc.nn_nb.sd_ratio']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.lin_simple.intercept  ...  ic.eps.s  \
# f_id i_id                                             ...
# 1    1      -0.236458                      -0.180859  ... -0.810853
#      2      -0.236458                      -0.180858  ... -0.769481
#      3      -0.236458                      -0.180859  ... -0.777748
#
#            nbc.nn_nb.sd_ratio
# f_id i_id
# 1    1               1.929558
#      2               1.244739
#      3               1.266448
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 7
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.678776     1
# 1                     ic.eps.ratio            0.129560     2
# 2               ela_distr.skewness            0.072803     3
# 3  ela_meta.quad_w_interact.adj_r2            0.066699     4
# 4     ela_meta.lin_simple.coef.max            0.065016     5
#
#
# topn_features: ['ic.eps.max', 'ic.eps.ratio', 'ela_distr.skewness', 'ela_meta.quad_w_interact.adj_r2', 'ela_meta.lin_simple.coef.max', 'ela_meta.lin_simple.intercept', 'ela_level.mmce_lda_10', 'ela_level.mmce_mda_10', 'nbc.nn_nb.mean_ratio', 'ic.eps.s']
# len topn_features: 10
# preview data:
#            ic.eps.max  ic.eps.ratio  ...  nbc.nn_nb.mean_ratio  ic.eps.s
# f_id i_id                            ...
# 1    1      -0.236775     -0.772271  ...              1.180816 -0.848594
#      2      -0.236774     -0.729160  ...              0.851355 -0.807686
#      3      -0.236774     -0.737816  ...              0.882436 -0.815860
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 8
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.629242     1
# 1                     ic.eps.ratio            0.098049     2
# 2  ela_meta.quad_w_interact.adj_r2            0.079271     3
# 3    ela_meta.lin_simple.intercept            0.078729     4
# 4               ela_distr.skewness            0.072778     5
#
#
# topn_features: ['ic.eps.max', 'ic.eps.ratio', 'ela_meta.quad_w_interact.adj_r2', 'ela_meta.lin_simple.intercept', 'ela_distr.skewness', 'ela_meta.lin_simple.coef.max', 'ic.eps.s', 'ela_level.mmce_lda_10', 'ela_level.mmce_mda_10', 'nbc.nn_nb.mean_ratio']
# len topn_features: 10
# preview data:
#            ic.eps.max  ic.eps.ratio  ...  ela_level.mmce_mda_10  \
# f_id i_id                            ...
# 1    1      -0.236516     -0.734582  ...               0.206586
#      2      -0.236516     -0.690831  ...              -1.686546
#      3      -0.236516     -0.699616  ...              -1.409857
#
#            nbc.nn_nb.mean_ratio
# f_id i_id
# 1    1                 1.206389
#      2                 0.874068
#      3                 0.905419
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 9
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.617947     1
# 1    ela_meta.lin_simple.intercept            0.120627     2
# 2                     ic.eps.ratio            0.097120     3
# 3               ela_distr.skewness            0.075545     4
# 4  ela_meta.quad_w_interact.adj_r2            0.072341     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.lin_simple.intercept', 'ic.eps.ratio', 'ela_distr.skewness', 'ela_meta.quad_w_interact.adj_r2', 'ela_meta.lin_simple.coef.max', 'ic.eps.s', 'ela_level.mmce_mda_10', 'ela_level.mmce_lda_10', 'nbc.nn_nb.mean_ratio']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.lin_simple.intercept  ...  \
# f_id i_id                                             ...
# 1    1      -0.236614                      -0.180891  ...
#      2      -0.236613                      -0.180891  ...
#      3      -0.236613                      -0.180892  ...
#
#            ela_level.mmce_lda_10  nbc.nn_nb.mean_ratio
# f_id i_id
# 1    1                  0.408471              1.228104
#      2                 -1.631981              0.892681
#      3                 -1.338256              0.924325
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 10
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.539798     1
# 1     ela_meta.lin_simple.coef.max            0.212762     2
# 2                     ic.eps.ratio            0.077637     3
# 3               ela_distr.skewness            0.074618     4
# 4  ela_meta.quad_w_interact.adj_r2            0.056553     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.lin_simple.coef.max', 'ic.eps.ratio', 'ela_distr.skewness', 'ela_meta.quad_w_interact.adj_r2', 'ic.eps.s', 'ela_meta.lin_simple.intercept', 'ela_level.mmce_mda_10', 'ela_level.mmce_lda_10', 'nbc.nn_nb.mean_ratio']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.lin_simple.coef.max  ...  \
# f_id i_id                                            ...
# 1    1      -0.225098                     -0.167831  ...
#      2      -0.225098                     -0.167831  ...
#      3      -0.225098                     -0.167831  ...
#
#            ela_level.mmce_lda_10  nbc.nn_nb.mean_ratio
# f_id i_id
# 1    1                  0.427670              1.152351
#      2                 -1.640718              0.823655
#      3                 -1.342972              0.854664
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 11
# Preview feature importance:
#                     feature_name  feature_importance  rank
# 0                     ic.eps.max            0.404497     1
# 1   ela_meta.lin_simple.coef.max            0.327652     2
# 2                       ic.eps.s            0.185738     3
# 3  ela_meta.lin_simple.intercept            0.105804     4
# 4             ela_distr.skewness            0.072937     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.lin_simple.coef.max', 'ic.eps.s', 'ela_meta.lin_simple.intercept', 'ela_distr.skewness', 'ela_meta.lin_simple.coef.min', 'ic.eps.ratio', 'ela_meta.quad_w_interact.adj_r2', 'ela_level.mmce_mda_10', 'ela_level.mmce_lda_10']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.lin_simple.coef.max  ...  \
# f_id i_id                                            ...
# 1    1       -0.22963                     -0.168225  ...
#      2       -0.22963                     -0.168225  ...
#      3       -0.22963                     -0.168225  ...
#
#            ela_level.mmce_mda_10  ela_level.mmce_lda_10
# f_id i_id
# 1    1                  0.251646               0.409993
#      2                 -1.653796              -1.631814
#      3                 -1.375308              -1.337894
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 12
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.566338     1
# 1    ela_meta.lin_simple.intercept            0.088925     2
# 2               ela_distr.skewness            0.069380     3
# 3                     ic.eps.ratio            0.066427     4
# 4  ela_meta.quad_w_interact.adj_r2            0.055146     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.lin_simple.intercept', 'ela_distr.skewness', 'ic.eps.ratio', 'ela_meta.quad_w_interact.adj_r2', 'ela_level.mmce_lda_10', 'ela_level.mmce_mda_10', 'ela_level.qda_mda_50', 'nbc.dist_ratio.coeff_var', 'nbc.nn_nb.mean_ratio']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.lin_simple.intercept  ...  \
# f_id i_id                                             ...
# 1    1      -0.382637                      -0.366333  ...
#      2      -0.382633                      -0.366269  ...
#      3      -0.382634                      -0.366380  ...
#
#            nbc.dist_ratio.coeff_var  nbc.nn_nb.mean_ratio
# f_id i_id
# 1    1                    -1.288006              1.185354
#      2                    -0.933080              0.855457
#      3                    -0.960173              0.886580
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 13
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.653622     1
# 1    ela_meta.lin_simple.intercept            0.143964     2
# 2  ela_meta.quad_w_interact.adj_r2            0.087340     3
# 3               ela_distr.skewness            0.072698     4
# 4                     ic.eps.ratio            0.050141     5
#
#
# topn_features: ['ic.eps.max', 'ela_meta.lin_simple.intercept', 'ela_meta.quad_w_interact.adj_r2', 'ela_distr.skewness', 'ic.eps.ratio', 'ela_meta.lin_simple.coef.max', 'ela_level.mmce_lda_10', 'disp.diff_mean_05', 'ic.eps.s', 'disp.ratio_median_05']
# len topn_features: 10
# preview data:
#            ic.eps.max  ela_meta.lin_simple.intercept  ...  ic.eps.s  \
# f_id i_id                                             ...
# 1    1      -0.236775                      -0.180905  ... -0.853806
#      2      -0.236774                      -0.180904  ... -0.812840
#      3      -0.236774                      -0.180905  ... -0.821025
#
#            disp.ratio_median_05
# f_id i_id
# 1    1                -1.349229
#      2                -0.940125
#      3                -0.929359
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 14
# Preview feature importance:
# ...
#
#
# topn_features: ['ela_meta.lin_simple.coef.min', 'ela_meta.quad_w_interact.adj_r2', 'ela_meta.lin_w_interact.adj_r2', 'ic.eps.max', 'ela_meta.lin_simple.coef.max_by_min', 'disp.diff_mean_02', 'disp.diff_median_02', 'ela_level.qda_mda_50', 'ela_meta.lin_simple.adj_r2', 'disp.ratio_median_02']
# len topn_features: 10
# preview data:
#            ela_meta.lin_simple.coef.min  ela_meta.quad_w_interact.adj_r2  ...  \
# f_id i_id                                                                 ...
# 1    1                        -0.176400                          0.66378  ...
#      2                        -0.176387                          0.66378  ...
#      3                        -0.176399                          0.66378  ...
#
#            ela_meta.lin_simple.adj_r2  disp.ratio_median_02
# f_id i_id
# 1    1                       0.518839             -1.312697
#      2                       1.358447             -0.966828
#      3                       1.300640             -0.994552
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 13
# Preview feature importance:
#                    feature_name  feature_importance  rank
# 0                    ic.eps.max            0.040167     1
# 1             disp.diff_mean_05            0.034382     2
# 2                      ic.eps.s            0.033874     3
# 3  ela_meta.lin_simple.coef.max            0.028656     4
# 4           disp.diff_median_25            0.028586     5
#
#
# topn_features: ['ic.eps.max', 'disp.diff_mean_05', 'ic.eps.s', 'ela_meta.lin_simple.coef.max', 'disp.diff_median_25', 'ela_level.lda_mda_25', 'ela_level.lda_qda_50', 'ela_level.mmce_mda_10', 'ela_level.lda_mda_10', 'ic.h.max']
# len topn_features: 10
# preview data:
#            ic.eps.max  disp.diff_mean_05  ...  ela_level.lda_mda_10  ic.h.max
# f_id i_id                                 ...
# 1    1      -0.236775          -1.449799  ...              0.435831  0.866556
#      2      -0.236774          -1.004312  ...              1.347713  0.661923
#      3      -0.236774          -0.994961  ...              1.076018  0.700603
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 14
# Preview feature importance:
#             feature_name  feature_importance  rank
# 0           ic.eps.ratio            0.036996     1
# 1     disp.ratio_mean_10            0.033965     2
# 2    disp.diff_median_25            0.032197     3
# 3   nbc.nn_nb.mean_ratio            0.031489     4
# 4  ela_level.mmce_mda_10            0.030762     5
#
#
# topn_features: ['ic.eps.ratio', 'disp.ratio_mean_10', 'disp.diff_median_25', 'nbc.nn_nb.mean_ratio', 'ela_level.mmce_mda_10', 'ela_level.lda_qda_50', 'ela_meta.lin_simple.coef.min', 'pca.expl_var_PC1.cov_init', 'ic.eps.s', 'pca.expl_var.cor_init']
# len topn_features: 10
# preview data:
#            ic.eps.ratio  disp.ratio_mean_10  ...  ic.eps.s  \
# f_id i_id                                    ...
# 1    1        -0.792068           -1.433222  ... -0.861613
#      2        -0.748669           -0.898703  ... -0.820537
#      3        -0.757383           -0.936275  ... -0.828744
#
#            pca.expl_var.cor_init
# f_id i_id
# 1    1                 -1.293993
#      2                 -1.293993
#      3                 -1.293993
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 15
# Preview feature importance:
#                    feature_name  feature_importance  rank
# 0            disp.ratio_mean_10            0.075751     1
# 1             disp.diff_mean_10            0.060379     2
# 2           disp.diff_median_25            0.041805     3
# 3            ela_distr.skewness            0.036168     4
# 4  ela_meta.lin_simple.coef.min            0.035979     5
#
#
# topn_features: ['disp.ratio_mean_10', 'disp.diff_mean_10', 'disp.diff_median_25', 'ela_distr.skewness', 'ela_meta.lin_simple.coef.min', 'ela_level.mmce_mda_10', 'ela_level.lda_mda_10', 'ic.eps.s', 'ela_level.mmce_lda_50', 'ela_level.mmce_qda_50']
# len topn_features: 10
# preview data:
#            disp.ratio_mean_10  disp.diff_mean_10  ...  ela_level.mmce_lda_50  \
# f_id i_id                                         ...
# 1    1              -1.470944          -1.470427  ...              -0.245625
#      2              -0.930977          -0.930889  ...              -0.886848
#      3              -0.968932          -0.968883  ...              -0.815362
#
#            ela_level.mmce_qda_50
# f_id i_id
# 1    1                 -0.131432
#      2                 -0.516111
#      3                 -0.462511
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 16
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0  ela_meta.quad_w_interact.adj_r2            0.047261     1
# 1                       ic.eps.max            0.039682     2
# 2                     ic.eps.ratio            0.038512     3
# 3     ela_meta.lin_simple.coef.max            0.034330     4
# 4                disp.diff_mean_05            0.033061     5
#
#
# topn_features: ['ela_meta.quad_w_interact.adj_r2', 'ic.eps.max', 'ic.eps.ratio', 'ela_meta.lin_simple.coef.max', 'disp.diff_mean_05', 'disp.ratio_mean_02', 'ela_level.lda_qda_50', 'disp.ratio_median_02', 'disp.ratio_mean_10', 'ela_level.lda_mda_25']
# len topn_features: 10
# preview data:
#            ela_meta.quad_w_interact.adj_r2  ic.eps.max  ...  \
# f_id i_id                                               ...
# 1    1                            0.682424   -0.236775  ...
#      2                            0.682424   -0.236775  ...
#      3                            0.682424   -0.236775  ...
#
#            disp.ratio_mean_10  ela_level.lda_mda_25
# f_id i_id
# 1    1              -1.501589             -0.320819
#      2              -0.899323             -0.322538
#      3              -0.941657             -0.331406
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 17
# Preview feature importance:
#             feature_name  feature_importance  rank
# 0  ela_level.mmce_mda_50            0.046613     1
# 1   ela_level.lda_mda_10            0.037988     2
# 2  ela_level.mmce_mda_10            0.036842     3
# 3     disp.ratio_mean_10            0.036024     4
# 4    disp.diff_median_25            0.031047     5
#
#
# topn_features: ['ela_level.mmce_mda_50', 'ela_level.lda_mda_10', 'ela_level.mmce_mda_10', 'disp.ratio_mean_10', 'disp.diff_median_25', 'ic.eps.s', 'ela_meta.lin_simple.intercept', 'pca.expl_var.cor_init', 'pca.expl_var_PC1.cor_init', 'ela_meta.lin_simple.coef.min']
# len topn_features: 10
# preview data:
#            ela_level.mmce_mda_50  ela_level.lda_mda_10  ...  \
# f_id i_id                                               ...
# 1    1                 -0.000215              0.379974  ...
#      2                 -0.571936              1.280550  ...
#      3                 -0.511316              1.012224  ...
#
#            pca.expl_var_PC1.cor_init  ela_meta.lin_simple.coef.min
# f_id i_id
# 1    1                      0.618382                      -0.13411
#      2                      1.225034                      -0.13411
#      3                      1.193764                      -0.13411
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 18
# Preview feature importance:
#             feature_name  feature_importance  rank
# 0     disp.ratio_mean_10            0.059415     1
# 1  ela_level.mmce_qda_50            0.047713     2
# 2   disp.ratio_median_05            0.043338     3
# 3  ela_level.mmce_mda_10            0.041292     4
# 4               ic.eps.s            0.040272     5
#
#
# topn_features: ['disp.ratio_mean_10', 'ela_level.mmce_qda_50', 'disp.ratio_median_05', 'ela_level.mmce_mda_10', 'ic.eps.s', 'disp.diff_median_25', 'ela_level.mmce_lda_50', 'ela_meta.quad_simple.adj_r2', 'ela_level.lda_mda_10', 'ela_meta.lin_simple.coef.min']
# len topn_features: 10
# preview data:
#            disp.ratio_mean_10  ela_level.mmce_qda_50  ...  \
# f_id i_id                                             ...
# 1    1              -1.427245              -0.116230  ...
#      2              -0.892909              -0.501052  ...
#      3              -0.930469              -0.447433  ...
#
#            ela_level.lda_mda_10  ela_meta.lin_simple.coef.min
# f_id i_id
# 1    1                 0.378749                      -0.13411
#      2                 1.279602                      -0.13411
#      3                 1.011194                      -0.13411
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 19
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.039208     1
# 1                         ic.eps.s            0.032937     2
# 2  ela_meta.quad_w_interact.adj_r2            0.028561     3
# 3     ela_meta.lin_simple.coef.max            0.028142     4
# 4              disp.diff_median_25            0.024345     5
#
#
# topn_features: ['ic.eps.max', 'ic.eps.s', 'ela_meta.quad_w_interact.adj_r2', 'ela_meta.lin_simple.coef.max', 'disp.diff_median_25', 'ela_level.lda_qda_50', 'disp.ratio_median_05', 'ela_level.qda_mda_10', 'ela_meta.lin_simple.coef.min', 'ela_level.mmce_qda_50']
# len topn_features: 10
# preview data:
#            ic.eps.max  ic.eps.s  ...  ela_meta.lin_simple.coef.min  \
# f_id i_id                        ...
# 1    1      -0.236775 -0.875813  ...                      -0.13411
#      2      -0.236775 -0.834491  ...                      -0.13411
#      3      -0.236775 -0.842747  ...                      -0.13411
#
#            ela_level.mmce_qda_50
# f_id i_id
# 1    1                 -0.108538
#      2                 -0.492704
#      3                 -0.439176
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 20
# Preview feature importance:
#                    feature_name  feature_importance  rank
# 0                    ic.eps.max            0.052320     1
# 1             disp.diff_mean_05            0.034783     2
# 2         ela_level.mmce_lda_10            0.029908     3
# 3                      ic.eps.s            0.029406     4
# 4  ela_meta.lin_simple.coef.max            0.026964     5
#
#
# topn_features: ['ic.eps.max', 'disp.diff_mean_05', 'ela_level.mmce_lda_10', 'ic.eps.s', 'ela_meta.lin_simple.coef.max', 'ela_level.mmce_mda_10', 'disp.ratio_mean_25', 'disp.ratio_median_02', 'disp.diff_median_25', 'disp.diff_median_05']
# len topn_features: 10
# preview data:
#            ic.eps.max  disp.diff_mean_05  ...  disp.diff_median_25  \
# f_id i_id                                 ...
# 1    1      -0.236703          -1.453126  ...            -1.413284
#      2      -0.236702          -1.007140  ...            -0.762461
#      3      -0.236703          -0.997780  ...            -0.815097
#
#            disp.diff_median_05
# f_id i_id
# 1    1               -1.348531
#      2               -0.940412
#      3               -0.930364
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 21
# Preview feature importance:
#                 feature_name  feature_importance  rank
# 0          disp.diff_mean_05            0.048988     1
# 1                 ic.eps.max            0.041340     2
# 2         disp.ratio_mean_05            0.036789     3
# 3        disp.diff_median_02            0.033829     4
# 4  pca.expl_var_PC1.cor_init            0.033786     5
#
#
# topn_features: ['disp.diff_mean_05', 'ic.eps.max', 'disp.ratio_mean_05', 'disp.diff_median_02', 'pca.expl_var_PC1.cor_init', 'disp.ratio_mean_10', 'ela_meta.quad_simple.adj_r2', 'ic.eps.s', 'ela_meta.lin_simple.coef.max', 'ela_level.lda_mda_25']
# len topn_features: 10
# preview data:
#            disp.diff_mean_05  ic.eps.max  ...  ela_meta.lin_simple.coef.max  \
# f_id i_id                                 ...
# 1    1             -1.394013   -0.236775  ...                      -0.16852
#      2             -0.942128   -0.236775  ...                      -0.16852
#      3             -0.932643   -0.236775  ...                      -0.16852
#
#            ela_level.lda_mda_25
# f_id i_id
# 1    1                -0.320816
#      2                -0.322535
#      3                -0.331403
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 22
# Preview feature importance:
#            feature_name  feature_importance  rank
# 0              ic.eps.s            0.049582     1
# 1   disp.diff_median_02            0.035961     2
# 2            ic.eps.max            0.033471     3
# 3    disp.ratio_mean_25            0.026320     4
# 4  ela_level.lda_mda_25            0.024971     5
#
#
# topn_features: ['ic.eps.s', 'disp.diff_median_02', 'ic.eps.max', 'disp.ratio_mean_25', 'ela_level.lda_mda_25', 'ela_level.mmce_mda_10', 'disp.diff_mean_05', 'disp.diff_mean_10', 'disp.diff_median_05', 'ela_level.lda_qda_50']
# len topn_features: 10
# preview data:
#            ic.eps.s  disp.diff_median_02  ...  disp.diff_median_05  \
# f_id i_id                                 ...
# 1    1    -0.906120            -1.243444  ...            -1.288640
#      2    -0.864140            -0.895694  ...            -0.878327
#      3    -0.872527            -0.924519  ...            -0.868226
#
#            ela_level.lda_qda_50
# f_id i_id
# 1    1                -0.240831
#      2                -0.398678
#      3                -0.392355
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 23
# Preview feature importance:
#                    feature_name  feature_importance  rank
# 0          disp.ratio_median_05            0.035500     1
# 1           disp.diff_median_02            0.034805     2
# 2           disp.diff_median_25            0.033974     3
# 3  ela_meta.lin_simple.coef.max            0.027045     4
# 4                    ic.eps.max            0.026786     5
#
#
# topn_features: ['disp.ratio_median_05', 'disp.diff_median_02', 'disp.diff_median_25', 'ela_meta.lin_simple.coef.max', 'ic.eps.max', 'disp.diff_mean_10', 'ela_meta.lin_simple.intercept', 'ic.eps.s', 'disp.diff_mean_25', 'ela_level.lda_qda_50']
# len topn_features: 10
# preview data:
#            disp.ratio_median_05  disp.diff_median_02  ...  disp.diff_mean_25  \
# f_id i_id                                             ...
# 1    1                -1.357938            -1.300925  ...          -1.545420
#      2                -0.904673            -0.921819  ...          -0.752806
#      3                -0.892745            -0.953244  ...          -0.827901
#
#            ela_level.lda_qda_50
# f_id i_id
# 1    1                -0.261023
#      2                -0.420106
#      3                -0.413734
#
# [3 rows x 10 columns]
# (115, 10)
# fold_number: 24
# Preview feature importance:
#                       feature_name  feature_importance  rank
# 0                       ic.eps.max            0.033152     1
# 1                         ic.eps.s            0.032773     2
# 2     ela_meta.lin_simple.coef.max            0.026200     3
# 3  ela_meta.quad_w_interact.adj_r2            0.023797     4
# 4                disp.diff_mean_02            0.021690     5
#
#
# topn_features: ['ic.eps.max', 'ic.eps.s', 'ela_meta.lin_simple.coef.max', 'ela_meta.quad_w_interact.adj_r2', 'disp.diff_mean_02', 'ic.eps.ratio', 'ela_level.qda_mda_10', 'disp.diff_mean_25', 'ela_meta.lin_simple.coef.min', 'nbc.nb_fitness.cor']
# len topn_features: 10
# preview data:
#            ic.eps.max  ic.eps.s  ...  ela_meta.lin_simple.coef.min  \
# f_id i_id                        ...
# 1    1      -0.236775 -0.869997  ...                      -0.13411
#      2      -0.236775 -0.828782  ...                      -0.13411
#      3      -0.236775 -0.837017  ...                      -0.13411
#
#            nbc.nb_fitness.cor
# f_id i_id
# 1    1              -0.505426
#      2              -0.023999
#      3              -0.051242
#
# [3 rows x 10 columns]
# (115, 10)
